# %%
import csv
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt 
import json

import landmarks_utils
from dataset_utils import Dataset
import process_heartrate as utils
from importlib import reload


csv_path = "dataset/dataset.csv"
dataset = Dataset(csv_path)

video_dir = "dataset/videos/"
landmarks_path = "dataset/outputs/landmarks/"
datastreams_path = "dataset/outputs/datastreams/"
frames_path = "dataset/outputs/frames/"
face_pose_path = "dataset/outputs/face_pose/"

fields, rows = dataset.open_csv()
reload(utils)
# Out:
# <module 'process_heartrate' from '/Users/phillipkim/projects/marvl-heartrate/process_heartrate.py'>

# %%
""" samples is a list containing all the id's of the videos that we will be experimenting with.
    We store in gt, the ground truth heart rate for each of these sample videos.
"""

samples = [2,4,6,7,8,9,10,11,12,13,14,16,17,18,19,20,21,22]
gt = {i: float(rows[i][fields.adjusted_hr_bpm]) for i in samples}

# %%
reload(utils)

def get_hr_median_res(window, step, mode="best", best_n=5):
    """
        Runs all videos through algorithm for predicting heartrate using the best_n method
        
        params:
            window - int representing size of window
            step - int representing step size
            mode - choice between "median", "mean", and "best"
            best_n - int representing the number of top stable windows to use for hr prediction
            
        returns:
            res_fft - dictionary mapping video id's to heartrate prediction made using FFT alg
            res_pos - dictionary mapping video id's to heartrate prediction made using POS alg
    """
    res_fft = {}
    res_pos = {}
    for filename in os.listdir(face_pose_path):
        if filename.find(".json") == -1: continue
        index = int(filename[:-5])
        if not os.path.exists(datastreams_path+str(index)+"/signal_1D.npy"): continue

        fps = float(rows[index][fields.vid_fps])
        signal_1d = np.load(datastreams_path+str(index)+"/signal_1D.npy")
        signal_3d = np.load(datastreams_path+str(index)+"/signal_3D.npy")

        f = open(face_pose_path+filename)
        pose_dict = json.loads(f.read())
        pose_vectors = [pose_dict[k] for k in pose_dict]

        hr_best_fft = utils.process_sliding_window(signal_1d, fps, window, step, utils.process_fft, mode, filter=True,best_n=best_n, pose_vectors=pose_vectors)
        hr_best_pos = utils.process_sliding_window(signal_3d, fps, window, step, utils.process_pos, mode, best_n=best_n, pose_vectors=pose_vectors)
        
        res_fft[index] = hr_best_fft * 60
        res_pos[index] = hr_best_pos * 60

    return res_fft, res_pos

# %%
import math

def get_rmse(res):
    """ global variable gt needed (maps id to ground truth heart rate)
        param:
            res - dictionary that maps id to heartrate prediction
        returns:
            rmse - float representing rmse between res and gt
    """
    
    err = 0
    count = 0
    for k, v in res.items():
        if k in gt and not math.isnan(v):
            err += (gt[k] - v)**2
            count += 1
    return math.sqrt(err / count)

# %%
# Choose hyperparameteres to experiment with below
windows = [3, 5, 7, 10, 12, 15, 20]
steps = [1, 2, 3, 5, 7, 10]
best_ns = [5, 7, 10, 15, 20]

best_rmse_fft = float('inf')
best_rmse_pos = float('inf')
best_params_fft = None
best_params_pos = None


""" Here, we loop through all combinations of parameters, storing the best combination of
    parameters. At the end, we print the best hyperparameter choices for both FFT and POS.
    We also store all results in the matrices rmse_matrix_fft and rmse_matrix_pos
"""
rmse_matrix_fft = np.zeros((len(windows), len(steps), len(best_ns)))
rmse_matrix_pos = np.zeros((len(windows), len(steps), len(best_ns)))
for i in range(len(windows)):
    for j in range(len(steps)):
        for k in range(len(best_ns)):
            window = windows[i]
            step = steps[j]
            best_n = best_ns[k]
            
            res_fft, res_pos = get_hr_median_res(window, step, mode="best", best_n=best_n)
            rmse_fft = get_rmse(res_fft)
            rmse_pos = get_rmse(res_pos)
            print("Params... window: {}, step: {}, best_n: {}".format(window, step, best_n))
            print("FFT RMSE: {}, POS RMSE: {}".format(rmse_fft, rmse_pos))
            print("-----")
            if rmse_fft < best_rmse_fft:
                best_rmse_fft = rmse_fft
                best_params_fft = {"window": window, "step": step, "best_n": best_n}
            if rmse_pos < best_rmse_pos:
                best_rmse_pos = rmse_pos
                best_params_pos = {"window": window, "step": step, "best_n": best_n}
                
            rmse_matrix_fft[i, j, k] = rmse_fft
            rmse_matrix_pos[i, j, k] = rmse_pos

print("Best FFT RMSE: {}, with params{}".format(best_rmse_fft, best_params_fft))
print("Best POS RMSE: {}, with params{}".format(best_rmse_pos, best_params_pos))
# Out:
# Params... window: 3, step: 1, best_n: 5
# FFT RMSE: 34.9658404602335, POS RMSE: 13.479281821482669
# -----
# Params... window: 3, step: 1, best_n: 7
# FFT RMSE: 32.3456749927885, POS RMSE: 11.311002914260607
# -----
# Params... window: 3, step: 1, best_n: 10
# FFT RMSE: 33.16629096805895, POS RMSE: 12.04569046749373
# -----
# Params... window: 3, step: 1, best_n: 15
# FFT RMSE: 33.08767559253012, POS RMSE: 11.055298782211892
# -----
# Params... window: 3, step: 1, best_n: 20
# FFT RMSE: 32.046269769409, POS RMSE: 11.228916656875676
# -----
# Params... window: 3, step: 2, best_n: 5
# FFT RMSE: 29.654012068147537, POS RMSE: 16.04966495705463
# -----
# Params... window: 3, step: 2, best_n: 7
# FFT RMSE: 31.111410964720626, POS RMSE: 13.71613126521268
# -----
# Params... window: 3, step: 2, best_n: 10
# FFT RMSE: 30.436990090647495, POS RMSE: 13.879429663781343
# -----
# Params... window: 3, step: 2, best_n: 15
# FFT RMSE: 29.55801091583154, POS RMSE: 14.841924955494354
# -----
# Params... window: 3, step: 2, best_n: 20
# FFT RMSE: 29.404219843443617, POS RMSE: 14.910675719438116
# -----
# Params... window: 3, step: 3, best_n: 5
# FFT RMSE: 39.94790861012283, POS RMSE: 15.34953238414227
# -----
# Params... window: 3, step: 3, best_n: 7
# FFT RMSE: 36.49110346313697, POS RMSE: 14.93455825030723
# -----
# Params... window: 3, step: 3, best_n: 10
# FFT RMSE: 34.68948124427524, POS RMSE: 14.413927311155714
# -----
# Params... window: 3, step: 3, best_n: 15
# FFT RMSE: 34.18392013001106, POS RMSE: 14.72214399198403
# -----
# Params... window: 3, step: 3, best_n: 20
# FFT RMSE: 34.18392013001106, POS RMSE: 14.72214399198403
# -----
# Params... window: 3, step: 5, best_n: 5
# FFT RMSE: 30.462988304861938, POS RMSE: 23.622332918038946
# -----
# Params... window: 3, step: 5, best_n: 7
# FFT RMSE: 29.831473573077496, POS RMSE: 21.035816687547474
# -----
# Params... window: 3, step: 5, best_n: 10
# FFT RMSE: 29.831473573077496, POS RMSE: 21.035816687547474
# -----
# Params... window: 3, step: 5, best_n: 15
# FFT RMSE: 29.831473573077496, POS RMSE: 21.035816687547474
# -----
# Params... window: 3, step: 5, best_n: 20
# FFT RMSE: 29.831473573077496, POS RMSE: 21.035816687547474
# -----
# Params... window: 3, step: 7, best_n: 5
# FFT RMSE: 35.01680549557085, POS RMSE: 14.688098012409126
# -----
# Params... window: 3, step: 7, best_n: 7
# FFT RMSE: 35.01680549557085, POS RMSE: 14.688098012409126
# -----
# Params... window: 3, step: 7, best_n: 10
# FFT RMSE: 35.01680549557085, POS RMSE: 14.688098012409126
# -----
# Params... window: 3, step: 7, best_n: 15
# FFT RMSE: 35.01680549557085, POS RMSE: 14.688098012409126
# -----
# Params... window: 3, step: 7, best_n: 20
# FFT RMSE: 35.01680549557085, POS RMSE: 14.688098012409126
# -----
# Params... window: 3, step: 10, best_n: 5
# FFT RMSE: 31.825041287005792, POS RMSE: 27.852671157720128
# -----
# Params... window: 3, step: 10, best_n: 7
# FFT RMSE: 31.825041287005792, POS RMSE: 27.852671157720128
# -----
# Params... window: 3, step: 10, best_n: 10
# FFT RMSE: 31.825041287005792, POS RMSE: 27.852671157720128
# -----
# Params... window: 3, step: 10, best_n: 15
# FFT RMSE: 31.825041287005792, POS RMSE: 27.852671157720128
# -----
# Params... window: 3, step: 10, best_n: 20
# FFT RMSE: 31.825041287005792, POS RMSE: 27.852671157720128
# -----
# Params... window: 5, step: 1, best_n: 5
# FFT RMSE: 30.340521910840366, POS RMSE: 14.475028678536477
# -----
# Params... window: 5, step: 1, best_n: 7
# FFT RMSE: 27.753438600383802, POS RMSE: 14.259278897486956
# -----
# Params... window: 5, step: 1, best_n: 10
# FFT RMSE: 26.991153428586703, POS RMSE: 14.287269621727539
# -----
# Params... window: 5, step: 1, best_n: 15
# FFT RMSE: 26.85612000731194, POS RMSE: 13.86561234417847
# -----
# Params... window: 5, step: 1, best_n: 20
# FFT RMSE: 24.945019968438274, POS RMSE: 14.184805846756031
# -----
# Params... window: 5, step: 2, best_n: 5
# FFT RMSE: 25.829487506886366, POS RMSE: 14.708680184471676
# -----
# Params... window: 5, step: 2, best_n: 7
# FFT RMSE: 27.250506810230103, POS RMSE: 14.751502821620063
# -----
# Params... window: 5, step: 2, best_n: 10
# FFT RMSE: 26.59284515782952, POS RMSE: 14.812145657559538
# -----
# Params... window: 5, step: 2, best_n: 15
# FFT RMSE: 24.636609110542274, POS RMSE: 14.715674573814036
# -----
# Params... window: 5, step: 2, best_n: 20
# FFT RMSE: 24.636609110542274, POS RMSE: 14.715674573814036
# -----
# Params... window: 5, step: 3, best_n: 5
# FFT RMSE: 31.928649355052123, POS RMSE: 13.271093685888808
# -----
# Params... window: 5, step: 3, best_n: 7
# FFT RMSE: 29.737151617411538, POS RMSE: 15.44052810492216
# -----
# Params... window: 5, step: 3, best_n: 10
# FFT RMSE: 26.564426126430572, POS RMSE: 16.15875947612548
# -----
# Params... window: 5, step: 3, best_n: 15
# FFT RMSE: 26.564426126430572, POS RMSE: 16.15875947612548
# -----
# Params... window: 5, step: 3, best_n: 20
# FFT RMSE: 26.564426126430572, POS RMSE: 16.15875947612548
# -----
# Params... window: 5, step: 5, best_n: 5
# FFT RMSE: 24.08864026391247, POS RMSE: 15.018443495874502
# -----
# Params... window: 5, step: 5, best_n: 7
# FFT RMSE: 23.09148740626757, POS RMSE: 16.058042416223515
# -----
# Params... window: 5, step: 5, best_n: 10
# FFT RMSE: 23.09148740626757, POS RMSE: 16.058042416223515
# -----
# Params... window: 5, step: 5, best_n: 15
# FFT RMSE: 23.09148740626757, POS RMSE: 16.058042416223515
# -----
# Params... window: 5, step: 5, best_n: 20
# FFT RMSE: 23.09148740626757, POS RMSE: 16.058042416223515
# -----
# Params... window: 5, step: 7, best_n: 5
# FFT RMSE: 27.310766569388324, POS RMSE: 16.300141297778893
# -----
# Params... window: 5, step: 7, best_n: 7
# FFT RMSE: 27.310766569388324, POS RMSE: 16.300141297778893
# -----
# Params... window: 5, step: 7, best_n: 10
# FFT RMSE: 27.310766569388324, POS RMSE: 16.300141297778893
# -----
# Params... window: 5, step: 7, best_n: 15
# FFT RMSE: 27.310766569388324, POS RMSE: 16.300141297778893
# -----
# Params... window: 5, step: 7, best_n: 20
# FFT RMSE: 27.310766569388324, POS RMSE: 16.300141297778893
# -----
# Params... window: 5, step: 10, best_n: 5
# FFT RMSE: 26.11264719747572, POS RMSE: 20.07865889296273
# -----
# Params... window: 5, step: 10, best_n: 7
# FFT RMSE: 26.11264719747572, POS RMSE: 20.07865889296273
# -----
# Params... window: 5, step: 10, best_n: 10
# FFT RMSE: 26.11264719747572, POS RMSE: 20.07865889296273
# -----
# Params... window: 5, step: 10, best_n: 15
# FFT RMSE: 26.11264719747572, POS RMSE: 20.07865889296273
# -----
# Params... window: 5, step: 10, best_n: 20
# FFT RMSE: 26.11264719747572, POS RMSE: 20.07865889296273
# -----
# Params... window: 7, step: 1, best_n: 5
# FFT RMSE: 32.12227864285005, POS RMSE: 17.88939087364643
# -----
# Params... window: 7, step: 1, best_n: 7
# FFT RMSE: 27.37620648176165, POS RMSE: 17.839726857433117
# -----
# Params... window: 7, step: 1, best_n: 10
# FFT RMSE: 25.360326891050054, POS RMSE: 17.014214567360877
# -----
# Params... window: 7, step: 1, best_n: 15
# FFT RMSE: 23.474544227341543, POS RMSE: 16.23996945673927
# -----
# Params... window: 7, step: 1, best_n: 20
# FFT RMSE: 24.53047771342151, POS RMSE: 14.98669525637124
# -----
# Params... window: 7, step: 2, best_n: 5
# FFT RMSE: 25.81198741560424, POS RMSE: 19.550687938075214
# -----
# Params... window: 7, step: 2, best_n: 7
# FFT RMSE: 24.335477217856326, POS RMSE: 17.176547937101034
# -----
# Params... window: 7, step: 2, best_n: 10
# FFT RMSE: 24.63350698214767, POS RMSE: 15.655198054853752
# -----
# Params... window: 7, step: 2, best_n: 15
# FFT RMSE: 22.394134158202245, POS RMSE: 15.221133413795789
# -----
# Params... window: 7, step: 2, best_n: 20
# FFT RMSE: 22.394134158202245, POS RMSE: 15.221133413795789
# -----
# Params... window: 7, step: 3, best_n: 5
# FFT RMSE: 26.13108228675123, POS RMSE: 16.667497647399703
# -----
# Params... window: 7, step: 3, best_n: 7
# FFT RMSE: 26.72979623516111, POS RMSE: 15.617112760771235
# -----
# Params... window: 7, step: 3, best_n: 10
# FFT RMSE: 24.199332377104668, POS RMSE: 15.41036004658768
# -----
# Params... window: 7, step: 3, best_n: 15
# FFT RMSE: 24.199332377104668, POS RMSE: 15.41036004658768
# -----
# Params... window: 7, step: 3, best_n: 20
# FFT RMSE: 24.199332377104668, POS RMSE: 15.41036004658768
# -----
# Params... window: 7, step: 5, best_n: 5
# FFT RMSE: 21.57492621095832, POS RMSE: 15.756296121920627
# -----
# Params... window: 7, step: 5, best_n: 7
# FFT RMSE: 20.923302982232425, POS RMSE: 15.305719664280373
# -----
# Params... window: 7, step: 5, best_n: 10
# FFT RMSE: 20.923302982232425, POS RMSE: 15.305719664280373
# -----
# Params... window: 7, step: 5, best_n: 15
# FFT RMSE: 20.923302982232425, POS RMSE: 15.305719664280373
# -----
# Params... window: 7, step: 5, best_n: 20
# FFT RMSE: 20.923302982232425, POS RMSE: 15.305719664280373
# -----
# Params... window: 7, step: 7, best_n: 5
# FFT RMSE: 21.210660718010672, POS RMSE: 18.214574429902854
# -----
# Params... window: 7, step: 7, best_n: 7
# FFT RMSE: 21.210660718010672, POS RMSE: 18.214574429902854
# -----
# Params... window: 7, step: 7, best_n: 10
# FFT RMSE: 21.210660718010672, POS RMSE: 18.214574429902854
# -----
# Params... window: 7, step: 7, best_n: 15
# FFT RMSE: 21.210660718010672, POS RMSE: 18.214574429902854
# -----
# Params... window: 7, step: 7, best_n: 20
# FFT RMSE: 21.210660718010672, POS RMSE: 18.214574429902854
# -----
# Params... window: 7, step: 10, best_n: 5
# FFT RMSE: 22.48084696765258, POS RMSE: 13.891375803011224
# -----
# Params... window: 7, step: 10, best_n: 7
# FFT RMSE: 22.48084696765258, POS RMSE: 13.891375803011224
# -----
# Params... window: 7, step: 10, best_n: 10
# FFT RMSE: 22.48084696765258, POS RMSE: 13.891375803011224
# -----
# Params... window: 7, step: 10, best_n: 15
# FFT RMSE: 22.48084696765258, POS RMSE: 13.891375803011224
# -----
# Params... window: 7, step: 10, best_n: 20
# FFT RMSE: 22.48084696765258, POS RMSE: 13.891375803011224
# -----
# Params... window: 10, step: 1, best_n: 5
# FFT RMSE: 26.539914774001723, POS RMSE: 20.675975048509006
# -----
# Params... window: 10, step: 1, best_n: 7
# FFT RMSE: 22.45456975937113, POS RMSE: 20.219646798921882
# -----
# Params... window: 10, step: 1, best_n: 10
# FFT RMSE: 21.425806645212223, POS RMSE: 19.47479762912894
# -----
# Params... window: 10, step: 1, best_n: 15
# FFT RMSE: 21.488224847171306, POS RMSE: 18.4638294215133
# -----
# Params... window: 10, step: 1, best_n: 20
# FFT RMSE: 21.091832332681008, POS RMSE: 18.308042675177003
# -----
# Params... window: 10, step: 2, best_n: 5
# FFT RMSE: 19.31365960302624, POS RMSE: 18.550517349379852
# -----
# Params... window: 10, step: 2, best_n: 7
# FFT RMSE: 19.573051729429825, POS RMSE: 17.981933592103694
# -----
# Params... window: 10, step: 2, best_n: 10
# FFT RMSE: 20.602125358191063, POS RMSE: 17.828337967251954
# -----
# Params... window: 10, step: 2, best_n: 15
# FFT RMSE: 19.356075457455365, POS RMSE: 17.60884327203984
# -----
# Params... window: 10, step: 2, best_n: 20
# FFT RMSE: 19.356075457455365, POS RMSE: 17.60884327203984
# -----
# Params... window: 10, step: 3, best_n: 5
# FFT RMSE: 28.223146212705803, POS RMSE: 19.51511722133357
# -----
# Params... window: 10, step: 3, best_n: 7
# FFT RMSE: 25.810454948208033, POS RMSE: 19.44746276541706
# -----
# Params... window: 10, step: 3, best_n: 10
# FFT RMSE: 23.81475616032043, POS RMSE: 18.579391513893775
# -----
# Params... window: 10, step: 3, best_n: 15
# FFT RMSE: 23.81475616032043, POS RMSE: 18.579391513893775
# -----
# Params... window: 10, step: 3, best_n: 20
# FFT RMSE: 23.81475616032043, POS RMSE: 18.579391513893775
# -----
# Params... window: 10, step: 5, best_n: 5
# FFT RMSE: 18.558955117010296, POS RMSE: 20.12929958712138
# -----
# Params... window: 10, step: 5, best_n: 7
# FFT RMSE: 18.558955117010296, POS RMSE: 20.12929958712138
# -----
# Params... window: 10, step: 5, best_n: 10
# FFT RMSE: 18.558955117010296, POS RMSE: 20.12929958712138
# -----
# Params... window: 10, step: 5, best_n: 15
# FFT RMSE: 18.558955117010296, POS RMSE: 20.12929958712138
# -----
# Params... window: 10, step: 5, best_n: 20
# FFT RMSE: 18.558955117010296, POS RMSE: 20.12929958712138
# -----
# Params... window: 10, step: 7, best_n: 5
# FFT RMSE: 22.526750794728688, POS RMSE: 20.323334523797325
# -----
# Params... window: 10, step: 7, best_n: 7
# FFT RMSE: 22.526750794728688, POS RMSE: 20.323334523797325
# -----
# Params... window: 10, step: 7, best_n: 10
# FFT RMSE: 22.526750794728688, POS RMSE: 20.323334523797325
# -----
# Params... window: 10, step: 7, best_n: 15
# FFT RMSE: 22.526750794728688, POS RMSE: 20.323334523797325
# -----
# Params... window: 10, step: 7, best_n: 20
# FFT RMSE: 22.526750794728688, POS RMSE: 20.323334523797325
# -----
# Params... window: 10, step: 10, best_n: 5
# FFT RMSE: 16.680244426028082, POS RMSE: 18.812251105054283
# -----
# Params... window: 10, step: 10, best_n: 7
# FFT RMSE: 16.680244426028082, POS RMSE: 18.812251105054283
# -----
# Params... window: 10, step: 10, best_n: 10
# FFT RMSE: 16.680244426028082, POS RMSE: 18.812251105054283
# -----
# Params... window: 10, step: 10, best_n: 15
# FFT RMSE: 16.680244426028082, POS RMSE: 18.812251105054283
# -----
# Params... window: 10, step: 10, best_n: 20
# FFT RMSE: 16.680244426028082, POS RMSE: 18.812251105054283
# -----
# Params... window: 12, step: 1, best_n: 5
# FFT RMSE: 28.35062077297921, POS RMSE: 22.272040720017397
# -----
# Params... window: 12, step: 1, best_n: 7
# FFT RMSE: 25.371667233441134, POS RMSE: 20.57942705398106
# -----
# Params... window: 12, step: 1, best_n: 10
# FFT RMSE: 23.628881148936607, POS RMSE: 18.762137808272303
# -----
# Params... window: 12, step: 1, best_n: 15
# FFT RMSE: 23.114046700421312, POS RMSE: 18.159944375703606
# -----
# Params... window: 12, step: 1, best_n: 20
# FFT RMSE: 20.750957078750194, POS RMSE: 18.048835443178092
# -----
# Params... window: 12, step: 2, best_n: 5
# FFT RMSE: 22.43428958209032, POS RMSE: 20.049347192944236
# -----
# Params... window: 12, step: 2, best_n: 7
# FFT RMSE: 23.06576636185067, POS RMSE: 18.492550076634117
# -----
# Params... window: 12, step: 2, best_n: 10
# FFT RMSE: 19.440675872241027, POS RMSE: 18.40172733829694
# -----
# Params... window: 12, step: 2, best_n: 15
# FFT RMSE: 18.969369087779235, POS RMSE: 18.2168429679648
# -----
# Params... window: 12, step: 2, best_n: 20
# FFT RMSE: 18.969369087779235, POS RMSE: 18.2168429679648
# -----
# Params... window: 12, step: 3, best_n: 5
# FFT RMSE: 25.362651395360054, POS RMSE: 19.82188415435264
# -----
# Params... window: 12, step: 3, best_n: 7
# FFT RMSE: 23.29024363050373, POS RMSE: 19.253322070189924
# -----
# Params... window: 12, step: 3, best_n: 10
# FFT RMSE: 23.285276886237398, POS RMSE: 19.1455433708215
# -----
# Params... window: 12, step: 3, best_n: 15
# FFT RMSE: 23.285276886237398, POS RMSE: 19.1455433708215
# -----
# Params... window: 12, step: 3, best_n: 20
# FFT RMSE: 23.285276886237398, POS RMSE: 19.1455433708215
# -----
# Params... window: 12, step: 5, best_n: 5
# FFT RMSE: 16.95567800318307, POS RMSE: 18.6689241369524
# -----
# Params... window: 12, step: 5, best_n: 7
# FFT RMSE: 16.95567800318307, POS RMSE: 18.6689241369524
# -----
# Params... window: 12, step: 5, best_n: 10
# FFT RMSE: 16.95567800318307, POS RMSE: 18.6689241369524
# -----
# Params... window: 12, step: 5, best_n: 15
# FFT RMSE: 16.95567800318307, POS RMSE: 18.6689241369524
# -----
# Params... window: 12, step: 5, best_n: 20
# FFT RMSE: 16.95567800318307, POS RMSE: 18.6689241369524
# -----
# Params... window: 12, step: 7, best_n: 5
# FFT RMSE: 15.553594104532571, POS RMSE: 21.110810607162268
# -----
# Params... window: 12, step: 7, best_n: 7
# FFT RMSE: 15.553594104532571, POS RMSE: 21.110810607162268
# -----
# Params... window: 12, step: 7, best_n: 10
# FFT RMSE: 15.553594104532571, POS RMSE: 21.110810607162268
# -----
# Params... window: 12, step: 7, best_n: 15
# FFT RMSE: 15.553594104532571, POS RMSE: 21.110810607162268
# -----
# Params... window: 12, step: 7, best_n: 20
# FFT RMSE: 15.553594104532571, POS RMSE: 21.110810607162268
# -----
# Params... window: 12, step: 10, best_n: 5
# FFT RMSE: 17.86841573705744, POS RMSE: 18.268606938830217
# -----
# Params... window: 12, step: 10, best_n: 7
# FFT RMSE: 17.86841573705744, POS RMSE: 18.268606938830217
# -----
# Params... window: 12, step: 10, best_n: 10
# FFT RMSE: 17.86841573705744, POS RMSE: 18.268606938830217
# -----
# Params... window: 12, step: 10, best_n: 15
# FFT RMSE: 17.86841573705744, POS RMSE: 18.268606938830217
# -----
# Params... window: 12, step: 10, best_n: 20
# FFT RMSE: 17.86841573705744, POS RMSE: 18.268606938830217
# -----
# Params... window: 15, step: 1, best_n: 5
# FFT RMSE: 24.84691523108346, POS RMSE: 20.610001953137402
# -----
# Params... window: 15, step: 1, best_n: 7
# FFT RMSE: 22.969558382062218, POS RMSE: 18.057829011151135
# -----
# Params... window: 15, step: 1, best_n: 10
# FFT RMSE: 20.777762741478295, POS RMSE: 16.836570353382335
# -----
# Params... window: 15, step: 1, best_n: 15
# FFT RMSE: 19.43253893492094, POS RMSE: 16.87620639672578
# -----
# Params... window: 15, step: 1, best_n: 20
# FFT RMSE: 18.52653286278906, POS RMSE: 17.20240976724307
# -----
# Params... window: 15, step: 2, best_n: 5
# FFT RMSE: 19.364409028876924, POS RMSE: 18.08282289801464
# -----
# Params... window: 15, step: 2, best_n: 7
# FFT RMSE: 20.34290590141562, POS RMSE: 17.572305711253254
# -----
# Params... window: 15, step: 2, best_n: 10
# FFT RMSE: 18.81161800585411, POS RMSE: 18.21696067607147
# -----
# Params... window: 15, step: 2, best_n: 15
# FFT RMSE: 18.81161800585411, POS RMSE: 18.21696067607147
# -----
# Params... window: 15, step: 2, best_n: 20
# FFT RMSE: 18.81161800585411, POS RMSE: 18.21696067607147
# -----
# Params... window: 15, step: 3, best_n: 5
# FFT RMSE: 23.186059210274976, POS RMSE: 16.47398616239444
# -----
# Params... window: 15, step: 3, best_n: 7
# FFT RMSE: 21.19450800037903, POS RMSE: 17.198337484765467
# -----
# Params... window: 15, step: 3, best_n: 10
# FFT RMSE: 21.19450800037903, POS RMSE: 17.198337484765467
# -----
# Params... window: 15, step: 3, best_n: 15
# FFT RMSE: 21.19450800037903, POS RMSE: 17.198337484765467
# -----
# Params... window: 15, step: 3, best_n: 20
# FFT RMSE: 21.19450800037903, POS RMSE: 17.198337484765467
# -----
# Params... window: 15, step: 5, best_n: 5
# FFT RMSE: 18.326390760044784, POS RMSE: 20.030065498970128
# -----
# Params... window: 15, step: 5, best_n: 7
# FFT RMSE: 18.326390760044784, POS RMSE: 20.030065498970128
# -----
# Params... window: 15, step: 5, best_n: 10
# FFT RMSE: 18.326390760044784, POS RMSE: 20.030065498970128
# -----
# Params... window: 15, step: 5, best_n: 15
# FFT RMSE: 18.326390760044784, POS RMSE: 20.030065498970128
# -----
# Params... window: 15, step: 5, best_n: 20
# FFT RMSE: 18.326390760044784, POS RMSE: 20.030065498970128
# -----
# Params... window: 15, step: 7, best_n: 5
# FFT RMSE: 20.46536313545171, POS RMSE: 18.56201695187378
# -----
# Params... window: 15, step: 7, best_n: 7
# FFT RMSE: 20.46536313545171, POS RMSE: 18.56201695187378
# -----
# Params... window: 15, step: 7, best_n: 10
# FFT RMSE: 20.46536313545171, POS RMSE: 18.56201695187378
# -----
# Params... window: 15, step: 7, best_n: 15
# FFT RMSE: 20.46536313545171, POS RMSE: 18.56201695187378
# -----
# Params... window: 15, step: 7, best_n: 20
# FFT RMSE: 20.46536313545171, POS RMSE: 18.56201695187378
# -----
# Params... window: 15, step: 10, best_n: 5
# FFT RMSE: 17.447404194740546, POS RMSE: 21.431072745128066
# -----
# Params... window: 15, step: 10, best_n: 7
# FFT RMSE: 17.447404194740546, POS RMSE: 21.431072745128066
# -----
# Params... window: 15, step: 10, best_n: 10
# FFT RMSE: 17.447404194740546, POS RMSE: 21.431072745128066
# -----
# Params... window: 15, step: 10, best_n: 15
# FFT RMSE: 17.447404194740546, POS RMSE: 21.431072745128066
# -----
# Params... window: 15, step: 10, best_n: 20
# FFT RMSE: 17.447404194740546, POS RMSE: 21.431072745128066
# -----
# Params... window: 20, step: 1, best_n: 5
# FFT RMSE: 17.896050552876876, POS RMSE: 17.912213758758483
# -----
# Params... window: 20, step: 1, best_n: 7
# FFT RMSE: 18.644527470244523, POS RMSE: 18.325211010225996
# -----
# Params... window: 20, step: 1, best_n: 10
# FFT RMSE: 16.51564436103093, POS RMSE: 18.38727387500977
# -----
# Params... window: 20, step: 1, best_n: 15
# FFT RMSE: 15.046209124924605, POS RMSE: 18.743738576980917
# -----
# Params... window: 20, step: 1, best_n: 20
# FFT RMSE: 15.046209124924605, POS RMSE: 18.743738576980917
# -----
# Params... window: 20, step: 2, best_n: 5
# FFT RMSE: 17.18135910387045, POS RMSE: 17.2876574974911
# -----
# Params... window: 20, step: 2, best_n: 7
# FFT RMSE: 14.893040168905497, POS RMSE: 17.975914004108475
# -----
# Params... window: 20, step: 2, best_n: 10
# FFT RMSE: 14.89179503870155, POS RMSE: 18.24361591256471
# -----
# Params... window: 20, step: 2, best_n: 15
# FFT RMSE: 14.89179503870155, POS RMSE: 18.24361591256471
# -----
# Params... window: 20, step: 2, best_n: 20
# FFT RMSE: 14.89179503870155, POS RMSE: 18.24361591256471
# -----
# Params... window: 20, step: 3, best_n: 5
# FFT RMSE: 13.331748898879786, POS RMSE: 19.87871425782265
# -----
# Params... window: 20, step: 3, best_n: 7
# FFT RMSE: 13.331748898879786, POS RMSE: 19.87871425782265
# -----
# Params... window: 20, step: 3, best_n: 10
# FFT RMSE: 13.331748898879786, POS RMSE: 19.87871425782265
# -----
# Params... window: 20, step: 3, best_n: 15
# FFT RMSE: 13.331748898879786, POS RMSE: 19.87871425782265
# -----
# Params... window: 20, step: 3, best_n: 20
# FFT RMSE: 13.331748898879786, POS RMSE: 19.87871425782265
# -----
# Params... window: 20, step: 5, best_n: 5
# FFT RMSE: 16.642581829337097, POS RMSE: 22.453179407632064
# -----
# Params... window: 20, step: 5, best_n: 7
# FFT RMSE: 16.642581829337097, POS RMSE: 22.453179407632064
# -----
# Params... window: 20, step: 5, best_n: 10
# FFT RMSE: 16.642581829337097, POS RMSE: 22.453179407632064
# -----
# Params... window: 20, step: 5, best_n: 15
# FFT RMSE: 16.642581829337097, POS RMSE: 22.453179407632064
# -----
# Params... window: 20, step: 5, best_n: 20
# FFT RMSE: 16.642581829337097, POS RMSE: 22.453179407632064
# -----
# Params... window: 20, step: 7, best_n: 5
# FFT RMSE: 10.631187025141063, POS RMSE: 18.662791316052463
# -----
# Params... window: 20, step: 7, best_n: 7
# FFT RMSE: 10.631187025141063, POS RMSE: 18.662791316052463
# -----
# Params... window: 20, step: 7, best_n: 10
# FFT RMSE: 10.631187025141063, POS RMSE: 18.662791316052463
# -----
# Params... window: 20, step: 7, best_n: 15
# FFT RMSE: 10.631187025141063, POS RMSE: 18.662791316052463
# -----
# Params... window: 20, step: 7, best_n: 20
# FFT RMSE: 10.631187025141063, POS RMSE: 18.662791316052463
# -----
# Params... window: 20, step: 10, best_n: 5
# FFT RMSE: 19.544275481620822, POS RMSE: 22.464535214665506
# -----
# Params... window: 20, step: 10, best_n: 7
# FFT RMSE: 19.544275481620822, POS RMSE: 22.464535214665506
# -----
# Params... window: 20, step: 10, best_n: 10
# FFT RMSE: 19.544275481620822, POS RMSE: 22.464535214665506
# -----
# Params... window: 20, step: 10, best_n: 15
# FFT RMSE: 19.544275481620822, POS RMSE: 22.464535214665506
# -----
# Params... window: 20, step: 10, best_n: 20
# FFT RMSE: 19.544275481620822, POS RMSE: 22.464535214665506
# -----
# Best FFT RMSE: 10.631187025141063, with params{'window': 20, 'step': 7, 'best_n': 5}
# Best POS RMSE: 11.055298782211892, with params{'window': 3, 'step': 1, 'best_n': 15}

# %% [markdown]
# The following cells plot the average RMSE against the hyperparameter choices

# %%
plt.plot(best_ns, np.mean(rmse_matrix_fft, axis=(0,1)))
plt.xlabel("best_n")
plt.ylabel("RMSE")
plt.title("FFT: best_n vs RMSE")
plt.show()
plt.plot(best_ns, np.mean(rmse_matrix_pos, axis=(0,1)))
plt.xlabel("best_n")
plt.ylabel("RMSE")
plt.title("POS: best_n vs RMSE")
plt.show()

# %%
plt.plot(windows, np.mean(rmse_matrix_fft, axis=(1,2)))
plt.xlabel("window size")
plt.ylabel("RMSE")
plt.title("FFT: window vs RMSE")
plt.show()
plt.plot(windows, np.mean(rmse_matrix_pos, axis=(1,2)))
plt.xlabel("window size")
plt.ylabel("RMSE")
plt.title("POS: window vs RMSE")
plt.show()

# %%
plt.plot(steps, np.mean(rmse_matrix_fft, axis=(0,2)))
plt.xlabel("step size")
plt.ylabel("RMSE")
plt.title("FFT: step size vs RMSE")
plt.show()
plt.plot(steps, np.mean(rmse_matrix_pos, axis=(0,2)))
plt.xlabel("step size")
plt.ylabel("RMSE")
plt.title("POS: step size vs RMSE")
plt.show()
